# %%
from pymeos.db.psycopg import MobilityDB
from pymeos import *
from datetime import datetime, timedelta
import time
from collections import deque
from pympler import asizeof
import gc
from enum import Enum
import numpy as np
from shapely.geometry import Point
import math
import subprocess
import shutil
import os
import sys

DIRECTORY_PATH = os.getcwd()
MATRIX_DIRECTORY_PATH = f'{DIRECTORY_PATH}/matrices'

# AIS Danish maritime dataset
DATABASE_NAME = "mobilitydb"
TPOINT_TABLE_NAME = "processed_data"
TPOINT_ID_COLUMN_NAME = "MMSI"
TPOINT_COLUMN_NAME = "traj"


class Database_connector:
    """
    Singleton class used to connect to the MobilityDB database.
    """
    
    def __init__(self):
        try: 
            connection_params = {
            "host": "localhost",
            "port": 5432,
            "dbname": DATABASE_NAME,
            "user": "postgres",
            "password": "postgres"
            }
            self.table_name = TPOINT_TABLE_NAME
            self.id_column_name = TPOINT_ID_COLUMN_NAME
            self.tpoint_column_name = TPOINT_COLUMN_NAME                  
            self.connection = MobilityDB.connect(**connection_params)

            self.cursor = self.connection.cursor()

            self.cursor.execute(f"SELECT {self.id_column_name} FROM public.{self.table_name};")
            self.ids_list = self.cursor.fetchall()
            self.ids_list = self.ids_list[:int(len(self.ids_list)*PERCENTAGE_OF_OBJECTS)]
        except Exception as e:
            pass

  
    def get_subset_of_tpoints(self, pstart, pend, xmin, ymin, xmax, ymax):
        """
        For each object in the ids_list :
            Fetch the subset of the associated Tpoints between the start and end timestamps
            contained in the STBOX defined by the xmin, ymin, xmax, ymax.
        """
        try:
           
            ids_list = [ f"'{id[0]}'"  for id in self.ids_list]
            ids_str = ', '.join(map(str, ids_list))
          
            query = f"""
                    SELECT 
                        atStbox(
                            a.{self.tpoint_column_name}::tgeompoint,
                            stbox(
                                ST_MakeEnvelope(
                                    {xmin}, {ymin}, -- xmin, ymin
                                    {xmax}, {ymax}, -- xmax, ymax
                                    4326 -- SRID
                                ),
                                tstzspan('[{pstart}, {pend}]')
                            )
                        )
                    FROM public.{self.table_name} as a 
                    WHERE a.{self.id_column_name} in ({ids_str})
                        AND a.{self.tpoint_column_name} IS NOT NULL;
                    """
            self.cursor.execute(query)
            rows = self.cursor.fetchall()
            return rows
        except Exception as e:
            self.log(e)


    def get_min_timestamp(self):
        """
        Returns the min timestamp of the tpoints columns.

        """
        try:
            
            self.cursor.execute(f"SELECT MIN(startTimestamp({self.tpoint_column_name})) AS earliest_timestamp FROM public.{self.table_name};")
            return self.cursor.fetchone()[0]
        except Exception as e:
            pass

    def get_max_timestamp(self):
        """
        Returns the max timestamp of the tpoints columns.

        """
        try:
            self.cursor.execute(f"SELECT MAX(endTimestamp({self.tpoint_column_name})) AS latest_timestamp FROM public.{self.table_name};")
            return self.cursor.fetchone()[0]
        except Exception as e:
            pass


    def close(self):
        """
        Close the connection to the MobilityDB database.
        """
        self.cursor.close()
        self.connection.close()




FPS_DEQUEUE_SIZE = 5 # Length of the dequeue to calculate the average FPS
TIME_DELTA_DEQUEUE_SIZE =  10 # Length of the dequeue to keep the keys to keep in the buffer


PERCENTAGE_OF_OBJECTS = 1 # To not overload the memory, we only take a percentage of the ships in the database
TIME_DELTA_SIZE = 240 # Number of frames associated to one Time delta
GRANULARITY = timedelta(minutes=1) # Time delta between two frames
SRID = 4326
FPS = 60

# %%
db = Database_connector()

start_date = db.get_min_timestamp()
end_date = db.get_max_timestamp()
total_frames = math.ceil( (end_date - start_date) // GRANULARITY )

timestamps = [start_date + i * GRANULARITY for i in range(total_frames)]
timestamps = [dt.replace(tzinfo=None) for dt in timestamps]
timestamps_strings = [dt.strftime('%Y-%m-%d %H:%M:%S') for dt in timestamps]

# %%
timestamps
# Out:
# [datetime.datetime(2023, 6, 1, 0, 0),
#  datetime.datetime(2023, 6, 1, 0, 1),
#  datetime.datetime(2023, 6, 1, 0, 2),
#  datetime.datetime(2023, 6, 1, 0, 3),
#  datetime.datetime(2023, 6, 1, 0, 4),
#  datetime.datetime(2023, 6, 1, 0, 5),
#  datetime.datetime(2023, 6, 1, 0, 6),
#  datetime.datetime(2023, 6, 1, 0, 7),
#  datetime.datetime(2023, 6, 1, 0, 8),
#  datetime.datetime(2023, 6, 1, 0, 9),
#  datetime.datetime(2023, 6, 1, 0, 10),
#  datetime.datetime(2023, 6, 1, 0, 11),
#  datetime.datetime(2023, 6, 1, 0, 12),
#  datetime.datetime(2023, 6, 1, 0, 13),
#  datetime.datetime(2023, 6, 1, 0, 14),
#  datetime.datetime(2023, 6, 1, 0, 15),
#  datetime.datetime(2023, 6, 1, 0, 16),
#  datetime.datetime(2023, 6, 1, 0, 17),
#  datetime.datetime(2023, 6, 1, 0, 18),
#  datetime.datetime(2023, 6, 1, 0, 19),
#  datetime.datetime(2023, 6, 1, 0, 20),
#  datetime.datetime(2023, 6, 1, 0, 21),
#  datetime.datetime(2023, 6, 1, 0, 22),
#  datetime.datetime(2023, 6, 1, 0, 23),
#  datetime.datetime(2023, 6, 1, 0, 24),
#  datetime.datetime(2023, 6, 1, 0, 25),
#  datetime.datetime(2023, 6, 1, 0, 26),
#  datetime.datetime(2023, 6, 1, 0, 27),
#  datetime.datetime(2023, 6, 1, 0, 28),
#  datetime.datetime(2023, 6, 1, 0, 29),
#  datetime.datetime(2023, 6, 1, 0, 30),
#  datetime.datetime(2023, 6, 1, 0, 31),
#  datetime.datetime(2023, 6, 1, 0, 32),
#  datetime.datetime(2023, 6, 1, 0, 33),
#  datetime.datetime(2023, 6, 1, 0, 34),
#  datetime.datetime(2023, 6, 1, 0, 35),
#  datetime.datetime(2023, 6, 1, 0, 36),
#  datetime.datetime(2023, 6, 1, 0, 37),
#  datetime.datetime(2023, 6, 1, 0, 38),
#  datetime.datetime(2023, 6, 1, 0, 39),
#  datetime.datetime(2023, 6, 1, 0, 40),
#  datetime.datetime(2023, 6, 1, 0, 41),
#  datetime.datetime(2023, 6, 1, 0, 42),
#  datetime.datetime(2023, 6, 1, 0, 43),
#  datetime.datetime(2023, 6, 1, 0, 44),
#  datetime.datetime(2023, 6, 1, 0, 45),
#  datetime.datetime(2023, 6, 1, 0, 46),
#  datetime.datetime(2023, 6, 1, 0, 47),
#  datetime.datetime(2023, 6, 1, 0, 48),
#  datetime.datetime(2023, 6, 1, 0, 49),
#  datetime.datetime(2023, 6, 1, 0, 50),
#  datetime.datetime(2023, 6, 1, 0, 51),
#  datetime.datetime(2023, 6, 1, 0, 52),
#  datetime.datetime(2023, 6, 1, 0, 53),
#  datetime.datetime(2023, 6, 1, 0, 54),
#  datetime.datetime(2023, 6, 1, 0, 55),
#  datetime.datetime(2023, 6, 1, 0, 56),
#  datetime.datetime(2023, 6, 1, 0, 57),
#  datetime.datetime(2023, 6, 1, 0, 58),
#  datetime.datetime(2023, 6, 1, 0, 59),
#  datetime.datetime(2023, 6, 1, 1, 0),
#  datetime.datetime(2023, 6, 1, 1, 1),
#  datetime.datetime(2023, 6, 1, 1, 2),
#  datetime.datetime(2023, 6, 1, 1, 3),
#  datetime.datetime(2023, 6, 1, 1, 4),
#  datetime.datetime(2023, 6, 1, 1, 5),
#  datetime.datetime(2023, 6, 1, 1, 6),
#  datetime.datetime(2023, 6, 1, 1, 7),
#  datetime.datetime(2023, 6, 1, 1, 8),
#  datetime.datetime(2023, 6, 1, 1, 9),
#  datetime.datetime(2023, 6, 1, 1, 10),
#  datetime.datetime(2023, 6, 1, 1, 11),
#  datetime.datetime(2023, 6, 1, 1, 12),
#  datetime.datetime(2023, 6, 1, 1, 13),
#  datetime.datetime(2023, 6, 1, 1, 14),
#  datetime.datetime(2023, 6, 1, 1, 15),
#  datetime.datetime(2023, 6, 1, 1, 16),
#  datetime.datetime(2023, 6, 1, 1, 17),
#  datetime.datetime(2023, 6, 1, 1, 18),
#  datetime.datetime(2023, 6, 1, 1, 19),
#  datetime.datetime(2023, 6, 1, 1, 20),
#  datetime.datetime(2023, 6, 1, 1, 21),
#  datetime.datetime(2023, 6, 1, 1, 22),
#  datetime.datetime(2023, 6, 1, 1, 23),
#  datetime.datetime(2023, 6, 1, 1, 24),
#  datetime.datetime(2023, 6, 1, 1, 25),
#  datetime.datetime(2023, 6, 1, 1, 26),
#  datetime.datetime(2023, 6, 1, 1, 27),
#  datetime.datetime(2023, 6, 1, 1, 28),
#  datetime.datetime(2023, 6, 1, 1, 29),
#  datetime.datetime(2023, 6, 1, 1, 30),
#  datetime.datetime(2023, 6, 1, 1, 31),
#  datetime.datetime(2023, 6, 1, 1, 32),
#  datetime.datetime(2023, 6, 1, 1, 33),
#  datetime.datetime(2023, 6, 1, 1, 34),
#  datetime.datetime(2023, 6, 1, 1, 35),
#  datetime.datetime(2023, 6, 1, 1, 36),
#  datetime.datetime(2023, 6, 1, 1, 37),
#  datetime.datetime(2023, 6, 1, 1, 38),
#  datetime.datetime(2023, 6, 1, 1, 39),
#  datetime.datetime(2023, 6, 1, 1, 40),
#  datetime.datetime(2023, 6, 1, 1, 41),
#  datetime.datetime(2023, 6, 1, 1, 42),
#  datetime.datetime(2023, 6, 1, 1, 43),
#  datetime.datetime(2023, 6, 1, 1, 44),
#  datetime.datetime(2023, 6, 1, 1, 45),
#  datetime.datetime(2023, 6, 1, 1, 46),
#  datetime.datetime(2023, 6, 1, 1, 47),
#  datetime.datetime(2023, 6, 1, 1, 48),
#  datetime.datetime(2023, 6, 1, 1, 49),
#  datetime.datetime(2023, 6, 1, 1, 50),
#  datetime.datetime(2023, 6, 1, 1, 51),
#  datetime.datetime(2023, 6, 1, 1, 52),
#  datetime.datetime(2023, 6, 1, 1, 53),
#  datetime.datetime(2023, 6, 1, 1, 54),
#  datetime.datetime(2023, 6, 1, 1, 55),
#  datetime.datetime(2023, 6, 1, 1, 56),
#  datetime.datetime(2023, 6, 1, 1, 57),
#  datetime.datetime(2023, 6, 1, 1, 58),
#  datetime.datetime(2023, 6, 1, 1, 59),
#  datetime.datetime(2023, 6, 1, 2, 0),
#  datetime.datetime(2023, 6, 1, 2, 1),
#  datetime.datetime(2023, 6, 1, 2, 2),
#  datetime.datetime(2023, 6, 1, 2, 3),
#  datetime.datetime(2023, 6, 1, 2, 4),
#  datetime.datetime(2023, 6, 1, 2, 5),
#  datetime.datetime(2023, 6, 1, 2, 6),
#  datetime.datetime(2023, 6, 1, 2, 7),
#  datetime.datetime(2023, 6, 1, 2, 8),
#  datetime.datetime(2023, 6, 1, 2, 9),
#  datetime.datetime(2023, 6, 1, 2, 10),
#  datetime.datetime(2023, 6, 1, 2, 11),
#  datetime.datetime(2023, 6, 1, 2, 12),
#  datetime.datetime(2023, 6, 1, 2, 13),
#  datetime.datetime(2023, 6, 1, 2, 14),
#  datetime.datetime(2023, 6, 1, 2, 15),
#  datetime.datetime(2023, 6, 1, 2, 16),
#  datetime.datetime(2023, 6, 1, 2, 17),
#  datetime.datetime(2023, 6, 1, 2, 18),
#  datetime.datetime(2023, 6, 1, 2, 19),
#  datetime.datetime(2023, 6, 1, 2, 20),
#  datetime.datetime(2023, 6, 1, 2, 21),
#  datetime.datetime(2023, 6, 1, 2, 22),
#  datetime.datetime(2023, 6, 1, 2, 23),
#  datetime.datetime(2023, 6, 1, 2, 24),
#  datetime.datetime(2023, 6, 1, 2, 25),
#  datetime.datetime(2023, 6, 1, 2, 26),
#  datetime.datetime(2023, 6, 1, 2, 27),
#  datetime.datetime(2023, 6, 1, 2, 28),
#  datetime.datetime(2023, 6, 1, 2, 29),
#  datetime.datetime(2023, 6, 1, 2, 30),
#  datetime.datetime(2023, 6, 1, 2, 31),
#  datetime.datetime(2023, 6, 1, 2, 32),
#  datetime.datetime(2023, 6, 1, 2, 33),
#  datetime.datetime(2023, 6, 1, 2, 34),
#  datetime.datetime(2023, 6, 1, 2, 35),
#  datetime.datetime(2023, 6, 1, 2, 36),
#  datetime.datetime(2023, 6, 1, 2, 37),
#  datetime.datetime(2023, 6, 1, 2, 38),
#  datetime.datetime(2023, 6, 1, 2, 39),
#  datetime.datetime(2023, 6, 1, 2, 40),
#  datetime.datetime(2023, 6, 1, 2, 41),
#  datetime.datetime(2023, 6, 1, 2, 42),
#  datetime.datetime(2023, 6, 1, 2, 43),
#  datetime.datetime(2023, 6, 1, 2, 44),
#  datetime.datetime(2023, 6, 1, 2, 45),
#  datetime.datetime(2023, 6, 1, 2, 46),
#  datetime.datetime(2023, 6, 1, 2, 47),
#  datetime.datetime(2023, 6, 1, 2, 48),
#  datetime.datetime(2023, 6, 1, 2, 49),
#  datetime.datetime(2023, 6, 1, 2, 50),
#  datetime.datetime(2023, 6, 1, 2, 51),
#  datetime.datetime(2023, 6, 1, 2, 52),
#  datetime.datetime(2023, 6, 1, 2, 53),
#  datetime.datetime(2023, 6, 1, 2, 54),
#  datetime.datetime(2023, 6, 1, 2, 55),
#  datetime.datetime(2023, 6, 1, 2, 56),
#  datetime.datetime(2023, 6, 1, 2, 57),
#  datetime.datetime(2023, 6, 1, 2, 58),
#  datetime.datetime(2023, 6, 1, 2, 59),
#  datetime.datetime(2023, 6, 1, 3, 0),
#  datetime.datetime(2023, 6, 1, 3, 1),
#  datetime.datetime(2023, 6, 1, 3, 2),
#  datetime.datetime(2023, 6, 1, 3, 3),
#  datetime.datetime(2023, 6, 1, 3, 4),
#  datetime.datetime(2023, 6, 1, 3, 5),
#  datetime.datetime(2023, 6, 1, 3, 6),
#  datetime.datetime(2023, 6, 1, 3, 7),
#  datetime.datetime(2023, 6, 1, 3, 8),
#  datetime.datetime(2023, 6, 1, 3, 9),
#  datetime.datetime(2023, 6, 1, 3, 10),
#  datetime.datetime(2023, 6, 1, 3, 11),
#  datetime.datetime(2023, 6, 1, 3, 12),
#  datetime.datetime(2023, 6, 1, 3, 13),
#  datetime.datetime(2023, 6, 1, 3, 14),
#  datetime.datetime(2023, 6, 1, 3, 15),
#  datetime.datetime(2023, 6, 1, 3, 16),
#  datetime.datetime(2023, 6, 1, 3, 17),
#  datetime.datetime(2023, 6, 1, 3, 18),
#  datetime.datetime(2023, 6, 1, 3, 19),
#  datetime.datetime(2023, 6, 1, 3, 20),
#  datetime.datetime(2023, 6, 1, 3, 21),
#  datetime.datetime(2023, 6, 1, 3, 22),
#  datetime.datetime(2023, 6, 1, 3, 23),
#  datetime.datetime(2023, 6, 1, 3, 24),
#  datetime.datetime(2023, 6, 1, 3, 25),
#  datetime.datetime(2023, 6, 1, 3, 26),
#  datetime.datetime(2023, 6, 1, 3, 27),
#  datetime.datetime(2023, 6, 1, 3, 28),
#  datetime.datetime(2023, 6, 1, 3, 29),
#  datetime.datetime(2023, 6, 1, 3, 30),
#  datetime.datetime(2023, 6, 1, 3, 31),
#  datetime.datetime(2023, 6, 1, 3, 32),
#  datetime.datetime(2023, 6, 1, 3, 33),
#  datetime.datetime(2023, 6, 1, 3, 34),
#  datetime.datetime(2023, 6, 1, 3, 35),
#  datetime.datetime(2023, 6, 1, 3, 36),
#  datetime.datetime(2023, 6, 1, 3, 37),
#  datetime.datetime(2023, 6, 1, 3, 38),
#  datetime.datetime(2023, 6, 1, 3, 39),
#  datetime.datetime(2023, 6, 1, 3, 40),
#  datetime.datetime(2023, 6, 1, 3, 41),
#  datetime.datetime(2023, 6, 1, 3, 42),
#  datetime.datetime(2023, 6, 1, 3, 43),
#  datetime.datetime(2023, 6, 1, 3, 44),
#  datetime.datetime(2023, 6, 1, 3, 45),
#  datetime.datetime(2023, 6, 1, 3, 46),
#  datetime.datetime(2023, 6, 1, 3, 47),
#  datetime.datetime(2023, 6, 1, 3, 48),
#  datetime.datetime(2023, 6, 1, 3, 49),
#  datetime.datetime(2023, 6, 1, 3, 50),
#  datetime.datetime(2023, 6, 1, 3, 51),
#  datetime.datetime(2023, 6, 1, 3, 52),
#  datetime.datetime(2023, 6, 1, 3, 53),
#  datetime.datetime(2023, 6, 1, 3, 54),
#  datetime.datetime(2023, 6, 1, 3, 55),
#  datetime.datetime(2023, 6, 1, 3, 56),
#  datetime.datetime(2023, 6, 1, 3, 57),
#  datetime.datetime(2023, 6, 1, 3, 58),
#  datetime.datetime(2023, 6, 1, 3, 59),
#  datetime.datetime(2023, 6, 1, 4, 0),
#  datetime.datetime(2023, 6, 1, 4, 1),
#  datetime.datetime(2023, 6, 1, 4, 2),
#  datetime.datetime(2023, 6, 1, 4, 3),
#  datetime.datetime(2023, 6, 1, 4, 4),
#  datetime.datetime(2023, 6, 1, 4, 5),
#  datetime.datetime(2023, 6, 1, 4, 6),
#  datetime.datetime(2023, 6, 1, 4, 7),
#  datetime.datetime(2023, 6, 1, 4, 8),
#  datetime.datetime(2023, 6, 1, 4, 9),
#  datetime.datetime(2023, 6, 1, 4, 10),
#  datetime.datetime(2023, 6, 1, 4, 11),
#  datetime.datetime(2023, 6, 1, 4, 12),
#  datetime.datetime(2023, 6, 1, 4, 13),
#  datetime.datetime(2023, 6, 1, 4, 14),
#  datetime.datetime(2023, 6, 1, 4, 15),
#  datetime.datetime(2023, 6, 1, 4, 16),
#  datetime.datetime(2023, 6, 1, 4, 17),
#  datetime.datetime(2023, 6, 1, 4, 18),
#  datetime.datetime(2023, 6, 1, 4, 19),
#  datetime.datetime(2023, 6, 1, 4, 20),
#  datetime.datetime(2023, 6, 1, 4, 21),
#  datetime.datetime(2023, 6, 1, 4, 22),
#  datetime.datetime(2023, 6, 1, 4, 23),
#  datetime.datetime(2023, 6, 1, 4, 24),
#  datetime.datetime(2023, 6, 1, 4, 25),
#  datetime.datetime(2023, 6, 1, 4, 26),
#  datetime.datetime(2023, 6, 1, 4, 27),
#  datetime.datetime(2023, 6, 1, 4, 28),
#  datetime.datetime(2023, 6, 1, 4, 29),
#  datetime.datetime(2023, 6, 1, 4, 30),
#  datetime.datetime(2023, 6, 1, 4, 31),
#  datetime.datetime(2023, 6, 1, 4, 32),
#  datetime.datetime(2023, 6, 1, 4, 33),
#  datetime.datetime(2023, 6, 1, 4, 34),
#  datetime.datetime(2023, 6, 1, 4, 35),
#  datetime.datetime(2023, 6, 1, 4, 36),
#  datetime.datetime(2023, 6, 1, 4, 37),
#  datetime.datetime(2023, 6, 1, 4, 38),
#  datetime.datetime(2023, 6, 1, 4, 39),
#  datetime.datetime(2023, 6, 1, 4, 40),
#  datetime.datetime(2023, 6, 1, 4, 41),
#  datetime.datetime(2023, 6, 1, 4, 42),
#  datetime.datetime(2023, 6, 1, 4, 43),
#  datetime.datetime(2023, 6, 1, 4, 44),
#  datetime.datetime(2023, 6, 1, 4, 45),
#  datetime.datetime(2023, 6, 1, 4, 46),
#  datetime.datetime(2023, 6, 1, 4, 47),
#  datetime.datetime(2023, 6, 1, 4, 48),
#  datetime.datetime(2023, 6, 1, 4, 49),
#  datetime.datetime(2023, 6, 1, 4, 50),
#  datetime.datetime(2023, 6, 1, 4, 51),
#  datetime.datetime(2023, 6, 1, 4, 52),
#  datetime.datetime(2023, 6, 1, 4, 53),
#  datetime.datetime(2023, 6, 1, 4, 54),
#  datetime.datetime(2023, 6, 1, 4, 55),
#  datetime.datetime(2023, 6, 1, 4, 56),
#  datetime.datetime(2023, 6, 1, 4, 57),
#  datetime.datetime(2023, 6, 1, 4, 58),
#  datetime.datetime(2023, 6, 1, 4, 59),
#  datetime.datetime(2023, 6, 1, 5, 0),
#  datetime.datetime(2023, 6, 1, 5, 1),
#  datetime.datetime(2023, 6, 1, 5, 2),
#  datetime.datetime(2023, 6, 1, 5, 3),
#  datetime.datetime(2023, 6, 1, 5, 4),
#  datetime.datetime(2023, 6, 1, 5, 5),
#  datetime.datetime(2023, 6, 1, 5, 6),
#  datetime.datetime(2023, 6, 1, 5, 7),
#  datetime.datetime(2023, 6, 1, 5, 8),
#  datetime.datetime(2023, 6, 1, 5, 9),
#  datetime.datetime(2023, 6, 1, 5, 10),
#  datetime.datetime(2023, 6, 1, 5, 11),
#  datetime.datetime(2023, 6, 1, 5, 12),
#  datetime.datetime(2023, 6, 1, 5, 13),
#  datetime.datetime(2023, 6, 1, 5, 14),
#  datetime.datetime(2023, 6, 1, 5, 15),
#  datetime.datetime(2023, 6, 1, 5, 16),
#  datetime.datetime(2023, 6, 1, 5, 17),
#  datetime.datetime(2023, 6, 1, 5, 18),
#  datetime.datetime(2023, 6, 1, 5, 19),
#  datetime.datetime(2023, 6, 1, 5, 20),
#  datetime.datetime(2023, 6, 1, 5, 21),
#  datetime.datetime(2023, 6, 1, 5, 22),
#  datetime.datetime(2023, 6, 1, 5, 23),
#  datetime.datetime(2023, 6, 1, 5, 24),
#  datetime.datetime(2023, 6, 1, 5, 25),
#  datetime.datetime(2023, 6, 1, 5, 26),
#  datetime.datetime(2023, 6, 1, 5, 27),
#  datetime.datetime(2023, 6, 1, 5, 28),
#  datetime.datetime(2023, 6, 1, 5, 29),
#  datetime.datetime(2023, 6, 1, 5, 30),
#  datetime.datetime(2023, 6, 1, 5, 31),
#  datetime.datetime(2023, 6, 1, 5, 32),
#  datetime.datetime(2023, 6, 1, 5, 33),
#  datetime.datetime(2023, 6, 1, 5, 34),
#  datetime.datetime(2023, 6, 1, 5, 35),
#  datetime.datetime(2023, 6, 1, 5, 36),
#  datetime.datetime(2023, 6, 1, 5, 37),
#  datetime.datetime(2023, 6, 1, 5, 38),
#  datetime.datetime(2023, 6, 1, 5, 39),
#  datetime.datetime(2023, 6, 1, 5, 40),
#  datetime.datetime(2023, 6, 1, 5, 41),
#  datetime.datetime(2023, 6, 1, 5, 42),
#  datetime.datetime(2023, 6, 1, 5, 43),
#  datetime.datetime(2023, 6, 1, 5, 44),
#  datetime.datetime(2023, 6, 1, 5, 45),
#  datetime.datetime(2023, 6, 1, 5, 46),
#  datetime.datetime(2023, 6, 1, 5, 47),
#  datetime.datetime(2023, 6, 1, 5, 48),
#  datetime.datetime(2023, 6, 1, 5, 49),
#  datetime.datetime(2023, 6, 1, 5, 50),
#  datetime.datetime(2023, 6, 1, 5, 51),
#  datetime.datetime(2023, 6, 1, 5, 52),
#  datetime.datetime(2023, 6, 1, 5, 53),
#  datetime.datetime(2023, 6, 1, 5, 54),
#  datetime.datetime(2023, 6, 1, 5, 55),
#  datetime.datetime(2023, 6, 1, 5, 56),
#  datetime.datetime(2023, 6, 1, 5, 57),
#  datetime.datetime(2023, 6, 1, 5, 58),
#  datetime.datetime(2023, 6, 1, 5, 59),
#  datetime.datetime(2023, 6, 1, 6, 0),
#  datetime.datetime(2023, 6, 1, 6, 1),
#  datetime.datetime(2023, 6, 1, 6, 2),
#  datetime.datetime(2023, 6, 1, 6, 3),
#  datetime.datetime(2023, 6, 1, 6, 4),
#  datetime.datetime(2023, 6, 1, 6, 5),
#  datetime.datetime(2023, 6, 1, 6, 6),
#  datetime.datetime(2023, 6, 1, 6, 7),
#  datetime.datetime(2023, 6, 1, 6, 8),
#  datetime.datetime(2023, 6, 1, 6, 9),
#  datetime.datetime(2023, 6, 1, 6, 10),
#  datetime.datetime(2023, 6, 1, 6, 11),
#  datetime.datetime(2023, 6, 1, 6, 12),
#  datetime.datetime(2023, 6, 1, 6, 13),
#  datetime.datetime(2023, 6, 1, 6, 14),
#  datetime.datetime(2023, 6, 1, 6, 15),
#  datetime.datetime(2023, 6, 1, 6, 16),
#  datetime.datetime(2023, 6, 1, 6, 17),
#  datetime.datetime(2023, 6, 1, 6, 18),
#  datetime.datetime(2023, 6, 1, 6, 19),
#  datetime.datetime(2023, 6, 1, 6, 20),
#  datetime.datetime(2023, 6, 1, 6, 21),
#  datetime.datetime(2023, 6, 1, 6, 22),
#  datetime.datetime(2023, 6, 1, 6, 23),
#  datetime.datetime(2023, 6, 1, 6, 24),
#  datetime.datetime(2023, 6, 1, 6, 25),
#  datetime.datetime(2023, 6, 1, 6, 26),
#  datetime.datetime(2023, 6, 1, 6, 27),
#  datetime.datetime(2023, 6, 1, 6, 28),
#  datetime.datetime(2023, 6, 1, 6, 29),
#  datetime.datetime(2023, 6, 1, 6, 30),
#  datetime.datetime(2023, 6, 1, 6, 31),
#  datetime.datetime(2023, 6, 1, 6, 32),
#  datetime.datetime(2023, 6, 1, 6, 33),
#  datetime.datetime(2023, 6, 1, 6, 34),
#  datetime.datetime(2023, 6, 1, 6, 35),
#  datetime.datetime(2023, 6, 1, 6, 36),
#  datetime.datetime(2023, 6, 1, 6, 37),
#  datetime.datetime(2023, 6, 1, 6, 38),
#  datetime.datetime(2023, 6, 1, 6, 39),
#  datetime.datetime(2023, 6, 1, 6, 40),
#  datetime.datetime(2023, 6, 1, 6, 41),
#  datetime.datetime(2023, 6, 1, 6, 42),
#  datetime.datetime(2023, 6, 1, 6, 43),
#  datetime.datetime(2023, 6, 1, 6, 44),
#  datetime.datetime(2023, 6, 1, 6, 45),
#  datetime.datetime(2023, 6, 1, 6, 46),
#  datetime.datetime(2023, 6, 1, 6, 47),
#  datetime.datetime(2023, 6, 1, 6, 48),
#  datetime.datetime(2023, 6, 1, 6, 49),
#  datetime.datetime(2023, 6, 1, 6, 50),
#  datetime.datetime(2023, 6, 1, 6, 51),
#  datetime.datetime(2023, 6, 1, 6, 52),
#  datetime.datetime(2023, 6, 1, 6, 53),
#  datetime.datetime(2023, 6, 1, 6, 54),
#  datetime.datetime(2023, 6, 1, 6, 55),
#  datetime.datetime(2023, 6, 1, 6, 56),
#  datetime.datetime(2023, 6, 1, 6, 57),
#  datetime.datetime(2023, 6, 1, 6, 58),
#  datetime.datetime(2023, 6, 1, 6, 59),
#  datetime.datetime(2023, 6, 1, 7, 0),
#  datetime.datetime(2023, 6, 1, 7, 1),
#  datetime.datetime(2023, 6, 1, 7, 2),
#  datetime.datetime(2023, 6, 1, 7, 3),
#  datetime.datetime(2023, 6, 1, 7, 4),
#  datetime.datetime(2023, 6, 1, 7, 5),
#  datetime.datetime(2023, 6, 1, 7, 6),
#  datetime.datetime(2023, 6, 1, 7, 7),
#  datetime.datetime(2023, 6, 1, 7, 8),
#  datetime.datetime(2023, 6, 1, 7, 9),
#  datetime.datetime(2023, 6, 1, 7, 10),
#  datetime.datetime(2023, 6, 1, 7, 11),
#  datetime.datetime(2023, 6, 1, 7, 12),
#  datetime.datetime(2023, 6, 1, 7, 13),
#  datetime.datetime(2023, 6, 1, 7, 14),
#  datetime.datetime(2023, 6, 1, 7, 15),
#  datetime.datetime(2023, 6, 1, 7, 16),
#  datetime.datetime(2023, 6, 1, 7, 17),
#  datetime.datetime(2023, 6, 1, 7, 18),
#  datetime.datetime(2023, 6, 1, 7, 19),
#  datetime.datetime(2023, 6, 1, 7, 20),
#  datetime.datetime(2023, 6, 1, 7, 21),
#  datetime.datetime(2023, 6, 1, 7, 22),
#  datetime.datetime(2023, 6, 1, 7, 23),
#  datetime.datetime(2023, 6, 1, 7, 24),
#  datetime.datetime(2023, 6, 1, 7, 25),
#  datetime.datetime(2023, 6, 1, 7, 26),
#  datetime.datetime(2023, 6, 1, 7, 27),
#  datetime.datetime(2023, 6, 1, 7, 28),
#  datetime.datetime(2023, 6, 1, 7, 29),
#  datetime.datetime(2023, 6, 1, 7, 30),
#  datetime.datetime(2023, 6, 1, 7, 31),
#  datetime.datetime(2023, 6, 1, 7, 32),
#  datetime.datetime(2023, 6, 1, 7, 33),
#  datetime.datetime(2023, 6, 1, 7, 34),
#  datetime.datetime(2023, 6, 1, 7, 35),
#  datetime.datetime(2023, 6, 1, 7, 36),
#  datetime.datetime(2023, 6, 1, 7, 37),
#  datetime.datetime(2023, 6, 1, 7, 38),
#  datetime.datetime(2023, 6, 1, 7, 39),
#  datetime.datetime(2023, 6, 1, 7, 40),
#  datetime.datetime(2023, 6, 1, 7, 41),
#  datetime.datetime(2023, 6, 1, 7, 42),
#  datetime.datetime(2023, 6, 1, 7, 43),
#  datetime.datetime(2023, 6, 1, 7, 44),
#  datetime.datetime(2023, 6, 1, 7, 45),
#  datetime.datetime(2023, 6, 1, 7, 46),
#  datetime.datetime(2023, 6, 1, 7, 47),
#  datetime.datetime(2023, 6, 1, 7, 48),
#  datetime.datetime(2023, 6, 1, 7, 49),
#  datetime.datetime(2023, 6, 1, 7, 50),
#  datetime.datetime(2023, 6, 1, 7, 51),
#  datetime.datetime(2023, 6, 1, 7, 52),
#  datetime.datetime(2023, 6, 1, 7, 53),
#  datetime.datetime(2023, 6, 1, 7, 54),
#  datetime.datetime(2023, 6, 1, 7, 55),
#  datetime.datetime(2023, 6, 1, 7, 56),
#  datetime.datetime(2023, 6, 1, 7, 57),
#  datetime.datetime(2023, 6, 1, 7, 58),
#  datetime.datetime(2023, 6, 1, 7, 59),
#  datetime.datetime(2023, 6, 1, 8, 0),
#  datetime.datetime(2023, 6, 1, 8, 1),
#  datetime.datetime(2023, 6, 1, 8, 2),
#  datetime.datetime(2023, 6, 1, 8, 3),
#  datetime.datetime(2023, 6, 1, 8, 4),
#  datetime.datetime(2023, 6, 1, 8, 5),
#  datetime.datetime(2023, 6, 1, 8, 6),
#  datetime.datetime(2023, 6, 1, 8, 7),
#  datetime.datetime(2023, 6, 1, 8, 8),
#  datetime.datetime(2023, 6, 1, 8, 9),
#  datetime.datetime(2023, 6, 1, 8, 10),
#  datetime.datetime(2023, 6, 1, 8, 11),
#  datetime.datetime(2023, 6, 1, 8, 12),
#  datetime.datetime(2023, 6, 1, 8, 13),
#  datetime.datetime(2023, 6, 1, 8, 14),
#  datetime.datetime(2023, 6, 1, 8, 15),
#  datetime.datetime(2023, 6, 1, 8, 16),
#  datetime.datetime(2023, 6, 1, 8, 17),
#  datetime.datetime(2023, 6, 1, 8, 18),
#  datetime.datetime(2023, 6, 1, 8, 19),
#  datetime.datetime(2023, 6, 1, 8, 20),
#  datetime.datetime(2023, 6, 1, 8, 21),
#  datetime.datetime(2023, 6, 1, 8, 22),
#  datetime.datetime(2023, 6, 1, 8, 23),
#  datetime.datetime(2023, 6, 1, 8, 24),
#  datetime.datetime(2023, 6, 1, 8, 25),
#  datetime.datetime(2023, 6, 1, 8, 26),
#  datetime.datetime(2023, 6, 1, 8, 27),
#  datetime.datetime(2023, 6, 1, 8, 28),
#  datetime.datetime(2023, 6, 1, 8, 29),
#  datetime.datetime(2023, 6, 1, 8, 30),
#  datetime.datetime(2023, 6, 1, 8, 31),
#  datetime.datetime(2023, 6, 1, 8, 32),
#  datetime.datetime(2023, 6, 1, 8, 33),
#  datetime.datetime(2023, 6, 1, 8, 34),
#  datetime.datetime(2023, 6, 1, 8, 35),
#  datetime.datetime(2023, 6, 1, 8, 36),
#  datetime.datetime(2023, 6, 1, 8, 37),
#  datetime.datetime(2023, 6, 1, 8, 38),
#  datetime.datetime(2023, 6, 1, 8, 39),
#  datetime.datetime(2023, 6, 1, 8, 40),
#  datetime.datetime(2023, 6, 1, 8, 41),
#  datetime.datetime(2023, 6, 1, 8, 42),
#  datetime.datetime(2023, 6, 1, 8, 43),
#  datetime.datetime(2023, 6, 1, 8, 44),
#  datetime.datetime(2023, 6, 1, 8, 45),
#  datetime.datetime(2023, 6, 1, 8, 46),
#  datetime.datetime(2023, 6, 1, 8, 47),
#  datetime.datetime(2023, 6, 1, 8, 48),
#  datetime.datetime(2023, 6, 1, 8, 49),
#  datetime.datetime(2023, 6, 1, 8, 50),
#  datetime.datetime(2023, 6, 1, 8, 51),
#  datetime.datetime(2023, 6, 1, 8, 52),
#  datetime.datetime(2023, 6, 1, 8, 53),
#  datetime.datetime(2023, 6, 1, 8, 54),
#  datetime.datetime(2023, 6, 1, 8, 55),
#  datetime.datetime(2023, 6, 1, 8, 56),
#  datetime.datetime(2023, 6, 1, 8, 57),
#  datetime.datetime(2023, 6, 1, 8, 58),
#  datetime.datetime(2023, 6, 1, 8, 59),
#  datetime.datetime(2023, 6, 1, 9, 0),
#  datetime.datetime(2023, 6, 1, 9, 1),
#  datetime.datetime(2023, 6, 1, 9, 2),
#  datetime.datetime(2023, 6, 1, 9, 3),
#  datetime.datetime(2023, 6, 1, 9, 4),
#  datetime.datetime(2023, 6, 1, 9, 5),
#  datetime.datetime(2023, 6, 1, 9, 6),
#  datetime.datetime(2023, 6, 1, 9, 7),
#  datetime.datetime(2023, 6, 1, 9, 8),
#  datetime.datetime(2023, 6, 1, 9, 9),
#  datetime.datetime(2023, 6, 1, 9, 10),
#  datetime.datetime(2023, 6, 1, 9, 11),
#  datetime.datetime(2023, 6, 1, 9, 12),
#  datetime.datetime(2023, 6, 1, 9, 13),
#  datetime.datetime(2023, 6, 1, 9, 14),
#  datetime.datetime(2023, 6, 1, 9, 15),
#  datetime.datetime(2023, 6, 1, 9, 16),
#  datetime.datetime(2023, 6, 1, 9, 17),
#  datetime.datetime(2023, 6, 1, 9, 18),
#  datetime.datetime(2023, 6, 1, 9, 19),
#  datetime.datetime(2023, 6, 1, 9, 20),
#  datetime.datetime(2023, 6, 1, 9, 21),
#  datetime.datetime(2023, 6, 1, 9, 22),
#  datetime.datetime(2023, 6, 1, 9, 23),
#  datetime.datetime(2023, 6, 1, 9, 24),
#  datetime.datetime(2023, 6, 1, 9, 25),
#  datetime.datetime(2023, 6, 1, 9, 26),
#  datetime.datetime(2023, 6, 1, 9, 27),
#  datetime.datetime(2023, 6, 1, 9, 28),
#  datetime.datetime(2023, 6, 1, 9, 29),
#  datetime.datetime(2023, 6, 1, 9, 30),
#  datetime.datetime(2023, 6, 1, 9, 31),
#  datetime.datetime(2023, 6, 1, 9, 32),
#  datetime.datetime(2023, 6, 1, 9, 33),
#  datetime.datetime(2023, 6, 1, 9, 34),
#  datetime.datetime(2023, 6, 1, 9, 35),
#  datetime.datetime(2023, 6, 1, 9, 36),
#  datetime.datetime(2023, 6, 1, 9, 37),
#  datetime.datetime(2023, 6, 1, 9, 38),
#  datetime.datetime(2023, 6, 1, 9, 39),
#  datetime.datetime(2023, 6, 1, 9, 40),
#  datetime.datetime(2023, 6, 1, 9, 41),
#  datetime.datetime(2023, 6, 1, 9, 42),
#  datetime.datetime(2023, 6, 1, 9, 43),
#  datetime.datetime(2023, 6, 1, 9, 44),
#  datetime.datetime(2023, 6, 1, 9, 45),
#  datetime.datetime(2023, 6, 1, 9, 46),
#  datetime.datetime(2023, 6, 1, 9, 47),
#  datetime.datetime(2023, 6, 1, 9, 48),
#  datetime.datetime(2023, 6, 1, 9, 49),
#  datetime.datetime(2023, 6, 1, 9, 50),
#  datetime.datetime(2023, 6, 1, 9, 51),
#  datetime.datetime(2023, 6, 1, 9, 52),
#  datetime.datetime(2023, 6, 1, 9, 53),
#  datetime.datetime(2023, 6, 1, 9, 54),
#  datetime.datetime(2023, 6, 1, 9, 55),
#  datetime.datetime(2023, 6, 1, 9, 56),
#  datetime.datetime(2023, 6, 1, 9, 57),
#  datetime.datetime(2023, 6, 1, 9, 58),
#  datetime.datetime(2023, 6, 1, 9, 59),
#  datetime.datetime(2023, 6, 1, 10, 0),
#  datetime.datetime(2023, 6, 1, 10, 1),
#  datetime.datetime(2023, 6, 1, 10, 2),
#  datetime.datetime(2023, 6, 1, 10, 3),
#  datetime.datetime(2023, 6, 1, 10, 4),
#  datetime.datetime(2023, 6, 1, 10, 5),
#  datetime.datetime(2023, 6, 1, 10, 6),
#  datetime.datetime(2023, 6, 1, 10, 7),
#  datetime.datetime(2023, 6, 1, 10, 8),
#  datetime.datetime(2023, 6, 1, 10, 9),
#  datetime.datetime(2023, 6, 1, 10, 10),
#  datetime.datetime(2023, 6, 1, 10, 11),
#  datetime.datetime(2023, 6, 1, 10, 12),
#  datetime.datetime(2023, 6, 1, 10, 13),
#  datetime.datetime(2023, 6, 1, 10, 14),
#  datetime.datetime(2023, 6, 1, 10, 15),
#  datetime.datetime(2023, 6, 1, 10, 16),
#  datetime.datetime(2023, 6, 1, 10, 17),
#  datetime.datetime(2023, 6, 1, 10, 18),
#  datetime.datetime(2023, 6, 1, 10, 19),
#  datetime.datetime(2023, 6, 1, 10, 20),
#  datetime.datetime(2023, 6, 1, 10, 21),
#  datetime.datetime(2023, 6, 1, 10, 22),
#  datetime.datetime(2023, 6, 1, 10, 23),
#  datetime.datetime(2023, 6, 1, 10, 24),
#  datetime.datetime(2023, 6, 1, 10, 25),
#  datetime.datetime(2023, 6, 1, 10, 26),
#  datetime.datetime(2023, 6, 1, 10, 27),
#  datetime.datetime(2023, 6, 1, 10, 28),
#  datetime.datetime(2023, 6, 1, 10, 29),
#  datetime.datetime(2023, 6, 1, 10, 30),
#  datetime.datetime(2023, 6, 1, 10, 31),
#  datetime.datetime(2023, 6, 1, 10, 32),
#  datetime.datetime(2023, 6, 1, 10, 33),
#  datetime.datetime(2023, 6, 1, 10, 34),
#  datetime.datetime(2023, 6, 1, 10, 35),
#  datetime.datetime(2023, 6, 1, 10, 36),
#  datetime.datetime(2023, 6, 1, 10, 37),
#  datetime.datetime(2023, 6, 1, 10, 38),
#  datetime.datetime(2023, 6, 1, 10, 39),
#  datetime.datetime(2023, 6, 1, 10, 40),
#  datetime.datetime(2023, 6, 1, 10, 41),
#  datetime.datetime(2023, 6, 1, 10, 42),
#  datetime.datetime(2023, 6, 1, 10, 43),
#  datetime.datetime(2023, 6, 1, 10, 44),
#  datetime.datetime(2023, 6, 1, 10, 45),
#  datetime.datetime(2023, 6, 1, 10, 46),
#  datetime.datetime(2023, 6, 1, 10, 47),
#  datetime.datetime(2023, 6, 1, 10, 48),
#  datetime.datetime(2023, 6, 1, 10, 49),
#  datetime.datetime(2023, 6, 1, 10, 50),
#  datetime.datetime(2023, 6, 1, 10, 51),
#  datetime.datetime(2023, 6, 1, 10, 52),
#  datetime.datetime(2023, 6, 1, 10, 53),
#  datetime.datetime(2023, 6, 1, 10, 54),
#  datetime.datetime(2023, 6, 1, 10, 55),
#  datetime.datetime(2023, 6, 1, 10, 56),
#  datetime.datetime(2023, 6, 1, 10, 57),
#  datetime.datetime(2023, 6, 1, 10, 58),
#  datetime.datetime(2023, 6, 1, 10, 59),
#  datetime.datetime(2023, 6, 1, 11, 0),
#  datetime.datetime(2023, 6, 1, 11, 1),
#  datetime.datetime(2023, 6, 1, 11, 2),
#  datetime.datetime(2023, 6, 1, 11, 3),
#  datetime.datetime(2023, 6, 1, 11, 4),
#  datetime.datetime(2023, 6, 1, 11, 5),
#  datetime.datetime(2023, 6, 1, 11, 6),
#  datetime.datetime(2023, 6, 1, 11, 7),
#  datetime.datetime(2023, 6, 1, 11, 8),
#  datetime.datetime(2023, 6, 1, 11, 9),
#  datetime.datetime(2023, 6, 1, 11, 10),
#  datetime.datetime(2023, 6, 1, 11, 11),
#  datetime.datetime(2023, 6, 1, 11, 12),
#  datetime.datetime(2023, 6, 1, 11, 13),
#  datetime.datetime(2023, 6, 1, 11, 14),
#  datetime.datetime(2023, 6, 1, 11, 15),
#  datetime.datetime(2023, 6, 1, 11, 16),
#  datetime.datetime(2023, 6, 1, 11, 17),
#  datetime.datetime(2023, 6, 1, 11, 18),
#  datetime.datetime(2023, 6, 1, 11, 19),
#  datetime.datetime(2023, 6, 1, 11, 20),
#  datetime.datetime(2023, 6, 1, 11, 21),
#  datetime.datetime(2023, 6, 1, 11, 22),
#  datetime.datetime(2023, 6, 1, 11, 23),
#  datetime.datetime(2023, 6, 1, 11, 24),
#  datetime.datetime(2023, 6, 1, 11, 25),
#  datetime.datetime(2023, 6, 1, 11, 26),
#  datetime.datetime(2023, 6, 1, 11, 27),
#  datetime.datetime(2023, 6, 1, 11, 28),
#  datetime.datetime(2023, 6, 1, 11, 29),
#  datetime.datetime(2023, 6, 1, 11, 30),
#  datetime.datetime(2023, 6, 1, 11, 31),
#  datetime.datetime(2023, 6, 1, 11, 32),
#  datetime.datetime(2023, 6, 1, 11, 33),
#  datetime.datetime(2023, 6, 1, 11, 34),
#  datetime.datetime(2023, 6, 1, 11, 35),
#  datetime.datetime(2023, 6, 1, 11, 36),
#  datetime.datetime(2023, 6, 1, 11, 37),
#  datetime.datetime(2023, 6, 1, 11, 38),
#  datetime.datetime(2023, 6, 1, 11, 39),
#  datetime.datetime(2023, 6, 1, 11, 40),
#  datetime.datetime(2023, 6, 1, 11, 41),
#  datetime.datetime(2023, 6, 1, 11, 42),
#  datetime.datetime(2023, 6, 1, 11, 43),
#  datetime.datetime(2023, 6, 1, 11, 44),
#  datetime.datetime(2023, 6, 1, 11, 45),
#  datetime.datetime(2023, 6, 1, 11, 46),
#  datetime.datetime(2023, 6, 1, 11, 47),
#  datetime.datetime(2023, 6, 1, 11, 48),
#  datetime.datetime(2023, 6, 1, 11, 49),
#  datetime.datetime(2023, 6, 1, 11, 50),
#  datetime.datetime(2023, 6, 1, 11, 51),
#  datetime.datetime(2023, 6, 1, 11, 52),
#  datetime.datetime(2023, 6, 1, 11, 53),
#  datetime.datetime(2023, 6, 1, 11, 54),
#  datetime.datetime(2023, 6, 1, 11, 55),
#  datetime.datetime(2023, 6, 1, 11, 56),
#  datetime.datetime(2023, 6, 1, 11, 57),
#  datetime.datetime(2023, 6, 1, 11, 58),
#  datetime.datetime(2023, 6, 1, 11, 59),
#  datetime.datetime(2023, 6, 1, 12, 0),
#  datetime.datetime(2023, 6, 1, 12, 1),
#  datetime.datetime(2023, 6, 1, 12, 2),
#  datetime.datetime(2023, 6, 1, 12, 3),
#  datetime.datetime(2023, 6, 1, 12, 4),
#  datetime.datetime(2023, 6, 1, 12, 5),
#  datetime.datetime(2023, 6, 1, 12, 6),
#  datetime.datetime(2023, 6, 1, 12, 7),
#  datetime.datetime(2023, 6, 1, 12, 8),
#  datetime.datetime(2023, 6, 1, 12, 9),
#  datetime.datetime(2023, 6, 1, 12, 10),
#  datetime.datetime(2023, 6, 1, 12, 11),
#  datetime.datetime(2023, 6, 1, 12, 12),
#  datetime.datetime(2023, 6, 1, 12, 13),
#  datetime.datetime(2023, 6, 1, 12, 14),
#  datetime.datetime(2023, 6, 1, 12, 15),
#  datetime.datetime(2023, 6, 1, 12, 16),
#  datetime.datetime(2023, 6, 1, 12, 17),
#  datetime.datetime(2023, 6, 1, 12, 18),
#  datetime.datetime(2023, 6, 1, 12, 19),
#  datetime.datetime(2023, 6, 1, 12, 20),
#  datetime.datetime(2023, 6, 1, 12, 21),
#  datetime.datetime(2023, 6, 1, 12, 22),
#  datetime.datetime(2023, 6, 1, 12, 23),
#  datetime.datetime(2023, 6, 1, 12, 24),
#  datetime.datetime(2023, 6, 1, 12, 25),
#  datetime.datetime(2023, 6, 1, 12, 26),
#  datetime.datetime(2023, 6, 1, 12, 27),
#  datetime.datetime(2023, 6, 1, 12, 28),
#  datetime.datetime(2023, 6, 1, 12, 29),
#  datetime.datetime(2023, 6, 1, 12, 30),
#  datetime.datetime(2023, 6, 1, 12, 31),
#  datetime.datetime(2023, 6, 1, 12, 32),
#  datetime.datetime(2023, 6, 1, 12, 33),
#  datetime.datetime(2023, 6, 1, 12, 34),
#  datetime.datetime(2023, 6, 1, 12, 35),
#  datetime.datetime(2023, 6, 1, 12, 36),
#  datetime.datetime(2023, 6, 1, 12, 37),
#  datetime.datetime(2023, 6, 1, 12, 38),
#  datetime.datetime(2023, 6, 1, 12, 39),
#  datetime.datetime(2023, 6, 1, 12, 40),
#  datetime.datetime(2023, 6, 1, 12, 41),
#  datetime.datetime(2023, 6, 1, 12, 42),
#  datetime.datetime(2023, 6, 1, 12, 43),
#  datetime.datetime(2023, 6, 1, 12, 44),
#  datetime.datetime(2023, 6, 1, 12, 45),
#  datetime.datetime(2023, 6, 1, 12, 46),
#  datetime.datetime(2023, 6, 1, 12, 47),
#  datetime.datetime(2023, 6, 1, 12, 48),
#  datetime.datetime(2023, 6, 1, 12, 49),
#  datetime.datetime(2023, 6, 1, 12, 50),
#  datetime.datetime(2023, 6, 1, 12, 51),
#  datetime.datetime(2023, 6, 1, 12, 52),
#  datetime.datetime(2023, 6, 1, 12, 53),
#  datetime.datetime(2023, 6, 1, 12, 54),
#  datetime.datetime(2023, 6, 1, 12, 55),
#  datetime.datetime(2023, 6, 1, 12, 56),
#  datetime.datetime(2023, 6, 1, 12, 57),
#  datetime.datetime(2023, 6, 1, 12, 58),
#  datetime.datetime(2023, 6, 1, 12, 59),
#  datetime.datetime(2023, 6, 1, 13, 0),
#  datetime.datetime(2023, 6, 1, 13, 1),
#  datetime.datetime(2023, 6, 1, 13, 2),
#  datetime.datetime(2023, 6, 1, 13, 3),
#  datetime.datetime(2023, 6, 1, 13, 4),
#  datetime.datetime(2023, 6, 1, 13, 5),
#  datetime.datetime(2023, 6, 1, 13, 6),
#  datetime.datetime(2023, 6, 1, 13, 7),
#  datetime.datetime(2023, 6, 1, 13, 8),
#  datetime.datetime(2023, 6, 1, 13, 9),
#  datetime.datetime(2023, 6, 1, 13, 10),
#  datetime.datetime(2023, 6, 1, 13, 11),
#  datetime.datetime(2023, 6, 1, 13, 12),
#  datetime.datetime(2023, 6, 1, 13, 13),
#  datetime.datetime(2023, 6, 1, 13, 14),
#  datetime.datetime(2023, 6, 1, 13, 15),
#  datetime.datetime(2023, 6, 1, 13, 16),
#  datetime.datetime(2023, 6, 1, 13, 17),
#  datetime.datetime(2023, 6, 1, 13, 18),
#  datetime.datetime(2023, 6, 1, 13, 19),
#  datetime.datetime(2023, 6, 1, 13, 20),
#  datetime.datetime(2023, 6, 1, 13, 21),
#  datetime.datetime(2023, 6, 1, 13, 22),
#  datetime.datetime(2023, 6, 1, 13, 23),
#  datetime.datetime(2023, 6, 1, 13, 24),
#  datetime.datetime(2023, 6, 1, 13, 25),
#  datetime.datetime(2023, 6, 1, 13, 26),
#  datetime.datetime(2023, 6, 1, 13, 27),
#  datetime.datetime(2023, 6, 1, 13, 28),
#  datetime.datetime(2023, 6, 1, 13, 29),
#  datetime.datetime(2023, 6, 1, 13, 30),
#  datetime.datetime(2023, 6, 1, 13, 31),
#  datetime.datetime(2023, 6, 1, 13, 32),
#  datetime.datetime(2023, 6, 1, 13, 33),
#  datetime.datetime(2023, 6, 1, 13, 34),
#  datetime.datetime(2023, 6, 1, 13, 35),
#  datetime.datetime(2023, 6, 1, 13, 36),
#  datetime.datetime(2023, 6, 1, 13, 37),
#  datetime.datetime(2023, 6, 1, 13, 38),
#  datetime.datetime(2023, 6, 1, 13, 39),
#  datetime.datetime(2023, 6, 1, 13, 40),
#  datetime.datetime(2023, 6, 1, 13, 41),
#  datetime.datetime(2023, 6, 1, 13, 42),
#  datetime.datetime(2023, 6, 1, 13, 43),
#  datetime.datetime(2023, 6, 1, 13, 44),
#  datetime.datetime(2023, 6, 1, 13, 45),
#  datetime.datetime(2023, 6, 1, 13, 46),
#  datetime.datetime(2023, 6, 1, 13, 47),
#  datetime.datetime(2023, 6, 1, 13, 48),
#  datetime.datetime(2023, 6, 1, 13, 49),
#  datetime.datetime(2023, 6, 1, 13, 50),
#  datetime.datetime(2023, 6, 1, 13, 51),
#  datetime.datetime(2023, 6, 1, 13, 52),
#  datetime.datetime(2023, 6, 1, 13, 53),
#  datetime.datetime(2023, 6, 1, 13, 54),
#  datetime.datetime(2023, 6, 1, 13, 55),
#  datetime.datetime(2023, 6, 1, 13, 56),
#  datetime.datetime(2023, 6, 1, 13, 57),
#  datetime.datetime(2023, 6, 1, 13, 58),
#  datetime.datetime(2023, 6, 1, 13, 59),
#  datetime.datetime(2023, 6, 1, 14, 0),
#  datetime.datetime(2023, 6, 1, 14, 1),
#  datetime.datetime(2023, 6, 1, 14, 2),
#  datetime.datetime(2023, 6, 1, 14, 3),
#  datetime.datetime(2023, 6, 1, 14, 4),
#  datetime.datetime(2023, 6, 1, 14, 5),
#  datetime.datetime(2023, 6, 1, 14, 6),
#  datetime.datetime(2023, 6, 1, 14, 7),
#  datetime.datetime(2023, 6, 1, 14, 8),
#  datetime.datetime(2023, 6, 1, 14, 9),
#  datetime.datetime(2023, 6, 1, 14, 10),
#  datetime.datetime(2023, 6, 1, 14, 11),
#  datetime.datetime(2023, 6, 1, 14, 12),
#  datetime.datetime(2023, 6, 1, 14, 13),
#  datetime.datetime(2023, 6, 1, 14, 14),
#  datetime.datetime(2023, 6, 1, 14, 15),
#  datetime.datetime(2023, 6, 1, 14, 16),
#  datetime.datetime(2023, 6, 1, 14, 17),
#  datetime.datetime(2023, 6, 1, 14, 18),
#  datetime.datetime(2023, 6, 1, 14, 19),
#  datetime.datetime(2023, 6, 1, 14, 20),
#  datetime.datetime(2023, 6, 1, 14, 21),
#  datetime.datetime(2023, 6, 1, 14, 22),
#  datetime.datetime(2023, 6, 1, 14, 23),
#  datetime.datetime(2023, 6, 1, 14, 24),
#  datetime.datetime(2023, 6, 1, 14, 25),
#  datetime.datetime(2023, 6, 1, 14, 26),
#  datetime.datetime(2023, 6, 1, 14, 27),
#  datetime.datetime(2023, 6, 1, 14, 28),
#  datetime.datetime(2023, 6, 1, 14, 29),
#  datetime.datetime(2023, 6, 1, 14, 30),
#  datetime.datetime(2023, 6, 1, 14, 31),
#  datetime.datetime(2023, 6, 1, 14, 32),
#  datetime.datetime(2023, 6, 1, 14, 33),
#  datetime.datetime(2023, 6, 1, 14, 34),
#  datetime.datetime(2023, 6, 1, 14, 35),
#  datetime.datetime(2023, 6, 1, 14, 36),
#  datetime.datetime(2023, 6, 1, 14, 37),
#  datetime.datetime(2023, 6, 1, 14, 38),
#  datetime.datetime(2023, 6, 1, 14, 39),
#  datetime.datetime(2023, 6, 1, 14, 40),
#  datetime.datetime(2023, 6, 1, 14, 41),
#  datetime.datetime(2023, 6, 1, 14, 42),
#  datetime.datetime(2023, 6, 1, 14, 43),
#  datetime.datetime(2023, 6, 1, 14, 44),
#  datetime.datetime(2023, 6, 1, 14, 45),
#  datetime.datetime(2023, 6, 1, 14, 46),
#  datetime.datetime(2023, 6, 1, 14, 47),
#  datetime.datetime(2023, 6, 1, 14, 48),
#  datetime.datetime(2023, 6, 1, 14, 49),
#  datetime.datetime(2023, 6, 1, 14, 50),
#  datetime.datetime(2023, 6, 1, 14, 51),
#  datetime.datetime(2023, 6, 1, 14, 52),
#  datetime.datetime(2023, 6, 1, 14, 53),
#  datetime.datetime(2023, 6, 1, 14, 54),
#  datetime.datetime(2023, 6, 1, 14, 55),
#  datetime.datetime(2023, 6, 1, 14, 56),
#  datetime.datetime(2023, 6, 1, 14, 57),
#  datetime.datetime(2023, 6, 1, 14, 58),
#  datetime.datetime(2023, 6, 1, 14, 59),
#  datetime.datetime(2023, 6, 1, 15, 0),
#  datetime.datetime(2023, 6, 1, 15, 1),
#  datetime.datetime(2023, 6, 1, 15, 2),
#  datetime.datetime(2023, 6, 1, 15, 3),
#  datetime.datetime(2023, 6, 1, 15, 4),
#  datetime.datetime(2023, 6, 1, 15, 5),
#  datetime.datetime(2023, 6, 1, 15, 6),
#  datetime.datetime(2023, 6, 1, 15, 7),
#  datetime.datetime(2023, 6, 1, 15, 8),
#  datetime.datetime(2023, 6, 1, 15, 9),
#  datetime.datetime(2023, 6, 1, 15, 10),
#  datetime.datetime(2023, 6, 1, 15, 11),
#  datetime.datetime(2023, 6, 1, 15, 12),
#  datetime.datetime(2023, 6, 1, 15, 13),
#  datetime.datetime(2023, 6, 1, 15, 14),
#  datetime.datetime(2023, 6, 1, 15, 15),
#  datetime.datetime(2023, 6, 1, 15, 16),
#  datetime.datetime(2023, 6, 1, 15, 17),
#  datetime.datetime(2023, 6, 1, 15, 18),
#  datetime.datetime(2023, 6, 1, 15, 19),
#  datetime.datetime(2023, 6, 1, 15, 20),
#  datetime.datetime(2023, 6, 1, 15, 21),
#  datetime.datetime(2023, 6, 1, 15, 22),
#  datetime.datetime(2023, 6, 1, 15, 23),
#  datetime.datetime(2023, 6, 1, 15, 24),
#  datetime.datetime(2023, 6, 1, 15, 25),
#  datetime.datetime(2023, 6, 1, 15, 26),
#  datetime.datetime(2023, 6, 1, 15, 27),
#  datetime.datetime(2023, 6, 1, 15, 28),
#  datetime.datetime(2023, 6, 1, 15, 29),
#  datetime.datetime(2023, 6, 1, 15, 30),
#  datetime.datetime(2023, 6, 1, 15, 31),
#  datetime.datetime(2023, 6, 1, 15, 32),
#  datetime.datetime(2023, 6, 1, 15, 33),
#  datetime.datetime(2023, 6, 1, 15, 34),
#  datetime.datetime(2023, 6, 1, 15, 35),
#  datetime.datetime(2023, 6, 1, 15, 36),
#  datetime.datetime(2023, 6, 1, 15, 37),
#  datetime.datetime(2023, 6, 1, 15, 38),
#  datetime.datetime(2023, 6, 1, 15, 39),
#  datetime.datetime(2023, 6, 1, 15, 40),
#  datetime.datetime(2023, 6, 1, 15, 41),
#  datetime.datetime(2023, 6, 1, 15, 42),
#  datetime.datetime(2023, 6, 1, 15, 43),
#  datetime.datetime(2023, 6, 1, 15, 44),
#  datetime.datetime(2023, 6, 1, 15, 45),
#  datetime.datetime(2023, 6, 1, 15, 46),
#  datetime.datetime(2023, 6, 1, 15, 47),
#  datetime.datetime(2023, 6, 1, 15, 48),
#  datetime.datetime(2023, 6, 1, 15, 49),
#  datetime.datetime(2023, 6, 1, 15, 50),
#  datetime.datetime(2023, 6, 1, 15, 51),
#  datetime.datetime(2023, 6, 1, 15, 52),
#  datetime.datetime(2023, 6, 1, 15, 53),
#  datetime.datetime(2023, 6, 1, 15, 54),
#  datetime.datetime(2023, 6, 1, 15, 55),
#  datetime.datetime(2023, 6, 1, 15, 56),
#  datetime.datetime(2023, 6, 1, 15, 57),
#  datetime.datetime(2023, 6, 1, 15, 58),
#  datetime.datetime(2023, 6, 1, 15, 59),
#  datetime.datetime(2023, 6, 1, 16, 0),
#  datetime.datetime(2023, 6, 1, 16, 1),
#  datetime.datetime(2023, 6, 1, 16, 2),
#  datetime.datetime(2023, 6, 1, 16, 3),
#  datetime.datetime(2023, 6, 1, 16, 4),
#  datetime.datetime(2023, 6, 1, 16, 5),
#  datetime.datetime(2023, 6, 1, 16, 6),
#  datetime.datetime(2023, 6, 1, 16, 7),
#  datetime.datetime(2023, 6, 1, 16, 8),
#  datetime.datetime(2023, 6, 1, 16, 9),
#  datetime.datetime(2023, 6, 1, 16, 10),
#  datetime.datetime(2023, 6, 1, 16, 11),
#  datetime.datetime(2023, 6, 1, 16, 12),
#  datetime.datetime(2023, 6, 1, 16, 13),
#  datetime.datetime(2023, 6, 1, 16, 14),
#  datetime.datetime(2023, 6, 1, 16, 15),
#  datetime.datetime(2023, 6, 1, 16, 16),
#  datetime.datetime(2023, 6, 1, 16, 17),
#  datetime.datetime(2023, 6, 1, 16, 18),
#  datetime.datetime(2023, 6, 1, 16, 19),
#  datetime.datetime(2023, 6, 1, 16, 20),
#  datetime.datetime(2023, 6, 1, 16, 21),
#  datetime.datetime(2023, 6, 1, 16, 22),
#  datetime.datetime(2023, 6, 1, 16, 23),
#  datetime.datetime(2023, 6, 1, 16, 24),
#  datetime.datetime(2023, 6, 1, 16, 25),
#  datetime.datetime(2023, 6, 1, 16, 26),
#  datetime.datetime(2023, 6, 1, 16, 27),
#  datetime.datetime(2023, 6, 1, 16, 28),
#  datetime.datetime(2023, 6, 1, 16, 29),
#  datetime.datetime(2023, 6, 1, 16, 30),
#  datetime.datetime(2023, 6, 1, 16, 31),
#  datetime.datetime(2023, 6, 1, 16, 32),
#  datetime.datetime(2023, 6, 1, 16, 33),
#  datetime.datetime(2023, 6, 1, 16, 34),
#  datetime.datetime(2023, 6, 1, 16, 35),
#  datetime.datetime(2023, 6, 1, 16, 36),
#  datetime.datetime(2023, 6, 1, 16, 37),
#  datetime.datetime(2023, 6, 1, 16, 38),
#  datetime.datetime(2023, 6, 1, 16, 39),
#  ...]

# %%
x_min = -180
y_min = -90
x_max = 180
y_max = 90

start_frame= 240
end_frame = 479

arguments = [start_frame, end_frame, PERCENTAGE_OF_OBJECTS, x_min, y_min, x_max, y_max]
arguments = [str(arg) for arg in arguments]
arguments += [timestamps_strings[0]  , str(len(timestamps)), "MINUTE", MATRIX_DIRECTORY_PATH, DATABASE_NAME, TPOINT_TABLE_NAME, TPOINT_ID_COLUMN_NAME, TPOINT_COLUMN_NAME]

# %%
arguments
# Out:
# ['240',
#  '479',
#  '1',
#  '-180',
#  '-90',
#  '180',
#  '90',
#  '2023-06-01 00:00:00',
#  '1439',
#  'MINUTE',
#  '/home/ali/QGIS-MobilityDB/experiment8_subprocess/matrices',
#  'mobilitydb',
#  'processed_data',
#  'MMSI',
#  'traj']

# %%
# Command to execute Program B
command = ['/usr/bin/python3', '/home/ali/QGIS-MobilityDB/experiment8_subprocess/matrix_file_processed.py', *arguments]
result = subprocess.run(command, capture_output=True, text=True)

# %%
result
# Out:
# CompletedProcess(args=['/usr/bin/python3', '/home/ali/QGIS-MobilityDB/experiment8_subprocess/matrix_file_processed.py', '240', '479', '1', '-180', '-90', '180', '90', '2023-06-01 00:00:00', '1439', 'MINUTE', '/home/ali/QGIS-MobilityDB/experiment8_subprocess/matrices', 'mobilitydb', 'processed_data', 'MMSI', 'traj'], returncode=0, stdout='start_index: 0, end_index: 239, => 240, len: 240\nstart_index: 0, end_index: 239, => 240, len: 240\nstart_index: 0, end_index: 239, => 240, len: 240\nstart_index: 0, end_index: 239, => 240, len: 240\nstart_index: 0, end_index: 239, => 240, len: 240\nstart_index: 237, end_index: 239, => 3, len: 3\nstart_index: 217, end_index: 239, => 23, len: 23\nstart_index: 218, end_index: 239, => 22, len: 22\nstart_index: 210, end_index: 239, => 30, len: 30\nstart_index: 0, end_index: 239, => 240, len: 240\nstart_index: 0, end_index: 140, => 141, len: 141\nstart_index: 0, end_index: 239, => 240, len: 240\nstart_index: 0, end_index: 239, => 240, len: 240\nstart_index: 0, end_index: 239, => 240, len: 240\nstart_index: 17, end_index: 239, => 223, len: 223\nstart_index: 0, end_index: 239, => 240, len: 240\nstart_index: 46, end_index: 111, => 66, len: 66\nstart_index: 233, end_index: 239, => 7, len: 7\nstart_index: 0, end_index: 239, => 240, len: 240\nstart_index: 25, end_index: 28, => 4, len: 4\nstart_index: 0, end_index: 239, => 240, len: 240\nstart_index: 0, end_index: 239, => 240, len: 240\nstart_index: 0, end_index: 239, => 240, len: 240\nstart_index: 0, end_index: 239, => 240, len: 240\nstart_index: 214, end_index: 239, => 26, len: 26\nstart_index: 0, end_index: 239, => 240, len: 240\nstart_index: 199, end_index: 239, => 41, len: 41\nstart_index: 0, end_index: 239, => 240, len: 240\nstart_index: 0, end_index: 239, => 240, len: 240\nstart_index: 0, end_index: 239, => 240, len: 240\nstart_index: 0, end_index: 239, => 240, len: 240\nstart_index: 0, end_index: 239, => 240, len: 240\nstart_index: 110, end_index: 239, => 130, len: 130\nstart_index: 71, end_index: 239, => 169, len: 169\nstart_index: 0, end_index: 239, => 240, len: 240\nstart_index: 0, end_index: 239, => 240, len: 240\nstart_index: 0, end_index: 239, => 240, len: 240\nstart_index: 0, end_index: 239, => 240, len: 240\nstart_index: 0, end_index: 239, => 240, len: 240\nstart_index: 0, end_index: 239, => 240, len: 240\nstart_index: 0, end_index: 239, => 240, len: 240\nstart_index: 0, end_index: 239, => 240, len: 240\nstart_index: 0, end_index: 239, => 240, len: 240\nstart_index: 0, end_index: 239, => 240, len: 240\nstart_index: 0, end_index: 239, => 240, len: 240\nstart_index: 0, end_index: 239, => 240, len: 240\nstart_index: 93, end_index: 239, => 147, len: 147\nstart_index: 0, end_index: 239, => 240, len: 240\nstart_index: 0, end_index: 239, => 240, len: 240\nstart_index: 0, end_index: 239, => 240, len: 240\nstart_index: 0, end_index: 239, => 240, len: 240\nstart_index: 0, end_index: 239, => 240, len: 240\nstart_index: 0, end_index: 239, => 240, len: 240\nstart_index: 0, end_index: 239, => 240, len: 240\nstart_index: 0, end_index: 239, => 240, len: 240\nstart_index: 0, end_index: 239, => 240, len: 240\nstart_index: 0, end_index: 239, => 240, len: 240\nstart_index: 0, end_index: 239, => 240, len: 240\nstart_index: 0, end_index: 239, => 240, len: 240\nstart_index: 0, end_index: 239, => 240, len: 240\nstart_index: 0, end_index: 239, => 240, len: 240\nstart_index: 145, end_index: 239, => 95, len: 95\nstart_index: 0, end_index: 239, => 240, len: 240\nstart_index: 0, end_index: 185, => 186, len: 186\nstart_index: 0, end_index: 239, => 240, len: 240\nstart_index: 0, end_index: 239, => 240, len: 240\nstart_index: 0, end_index: 239, => 240, len: 240\nstart_index: 0, end_index: 193, => 194, len: 194\nstart_index: 0, end_index: 239, => 240, len: 240\nstart_index: 0, end_index: 239, => 240, len: 240\nstart_index: 0, end_index: 239, => 240, len: 240\nstart_index: 16, end_index: 239, => 224, len: 224\nstart_index: 0, end_index: 239, => 240, len: 240\nstart_index:  ...

# %% [markdown]
# import numpy as np
#
# # Load the .npy file with allow_pickle set to True
# loaded_matrix = np.load('matrix_0.npy', allow_pickle=True)
#
# print(loaded_matrix)

# %% [markdown]
# # Debugging process B code

# %%
sysargs = arguments
sysargs
# Out:
# ['0',
#  '240',
#  '1',
#  '-180',
#  '-90',
#  '180',
#  '90',
#  '2023-06-01 00:00:00',
#  '1439',
#  'MINUTE',
#  '/home/ali/QGIS-MobilityDB/experiment8_subprocess/matrices',
#  'mobilitydb',
#  'processed_data',
#  'MMSI',
#  'traj']

# %%
import numpy as np
from shapely.geometry import Point
from pymeos.db.psycopg import MobilityDB

from pymeos import *
import os
import sys
from datetime import timedelta, datetime
from pymeos import *
import time



now = time.time()

FPS_DEQUEUE_SIZE = 5 # Length of the dequeue to calculate the average FPS
TIME_DELTA_DEQUEUE_SIZE =  10 # Length of the dequeue to keep the keys to keep in the buffer


args = sysargs

begin_frame = 240
end_frame = 479
TIME_DELTA_SIZE = end_frame - begin_frame + 1
PERCENTAGE_OF_OBJECTS = float(args[2])


GRANULARITY = timedelta(minutes=1) # Time delta between two frames
SRID = 4326
FPS = 60



class Database_connector:
    """
    Singleton class used to connect to the MobilityDB database.
    """
    
    def __init__(self):
        try: 
            connection_params = {
            "host": "localhost",
            "port": 5432,
            "dbname": "mobilitydb",
            "user": "postgres",
            "password": "postgres"
            }
            self.table_name = "PyMEOS_demo"
            self.id_column_name = "MMSI"
            self.tpoint_column_name = "trajectory"                    
            self.connection = MobilityDB.connect(**connection_params)

            self.cursor = self.connection.cursor()

            self.cursor.execute(f"SELECT {self.id_column_name} FROM public.{self.table_name};")
            self.ids_list = self.cursor.fetchall()
            self.ids_list = self.ids_list[:int(len(self.ids_list)*PERCENTAGE_OF_OBJECTS)]
        except Exception as e:
            pass

  
    def get_subset_of_tpoints(self, pstart, pend, xmin, ymin, xmax, ymax):
        """
        For each object in the ids_list :
            Fetch the subset of the associated Tpoints between the start and end timestamps
            contained in the STBOX defined by the xmin, ymin, xmax, ymax.
        """
        try:
           
            ids_list = [ f"'{id[0]}'"  for id in self.ids_list]
            ids_str = ', '.join(map(str, ids_list))
          
            query = f"""
                    SELECT 
                        atStbox(
                            a.{self.tpoint_column_name}::tgeompoint,
                            stbox(
                                ST_MakeEnvelope(
                                    {xmin}, {ymin}, -- xmin, ymin
                                    {xmax}, {ymax}, -- xmax, ymax
                                    4326 -- SRID
                                ),
                                tstzspan('[{pstart}, {pend}]')
                            )
                        )
                    FROM public.{self.table_name} as a 
                    WHERE a.{self.id_column_name} in ({ids_str});
                    """
            self.cursor.execute(query)
            # print(query)
            rows = self.cursor.fetchall()
            return rows
        except Exception as e:
            # print(e)
            pass


    def get_min_timestamp(self):
        """
        Returns the min timestamp of the tpoints columns.

        """
        try:
            
            self.cursor.execute(f"SELECT MIN(startTimestamp({self.tpoint_column_name})) AS earliest_timestamp FROM public.{self.table_name};")
            return self.cursor.fetchone()[0]
        except Exception as e:
            pass

    def get_max_timestamp(self):
        """
        Returns the max timestamp of the tpoints columns.

        """
        try:
            self.cursor.execute(f"SELECT MAX(endTimestamp({self.tpoint_column_name})) AS latest_timestamp FROM public.{self.table_name};")
            return self.cursor.fetchone()[0]
        except Exception as e:
            pass


    def close(self):
        """
        Close the connection to the MobilityDB database.
        """
        self.cursor.close()
        self.connection.close()



file_name = f"/home/ali/matrices/matrix_{begin_frame}.npy"
GRANULARITY = timedelta(minutes=1)

# check if file does't already exist


pymeos_initialize()
db = Database_connector()

x_min = float(args[3])
y_min = float(args[4])
x_max = float(args[5])
y_max = float(args[6])

timestamps = args[7:]
# transform the timestamps to datetime objects
timestamps = [datetime.strptime(timestamp, '%Y-%m-%d %H:%M:%S') for timestamp in timestamps]

p_start = timestamps[begin_frame]
p_end = timestamps[end_frame]
# print(p_start, p_end, x_min, y_min, x_max, y_max)
rows = db.get_subset_of_tpoints(p_start, p_end, x_min, y_min, x_max, y_max)    
    
        
empty_point_wkt = Point().wkt  # "POINT EMPTY"
matrix = np.full((len(rows), TIME_DELTA_SIZE), empty_point_wkt, dtype=object)

time_ranges = timestamps
now = time.time()


for i in range(len(rows)):
    try:
        traj = rows[i][0]
        traj = traj.temporal_precision(GRANULARITY) 
        num_instants = traj.num_instants()
        if num_instants == 0:
            continue
        elif num_instants == 1:
            single_timestamp = traj.timestamps()[0].replace(tzinfo=None)
            index = time_ranges.index(single_timestamp) - begin_frame
            matrix[i][index] = traj.values()[0].wkt
            
        elif num_instants >= 2:
            traj_resampled = traj.temporal_sample(start=time_ranges[0],duration= GRANULARITY)
            
            start_index = time_ranges.index( traj_resampled.start_timestamp().replace(tzinfo=None) ) - begin_frame
            end_index = time_ranges.index( traj_resampled.end_timestamp().replace(tzinfo=None) ) - begin_frame
    
            trajectory_array = np.array([point.wkt for point in traj_resampled.values()])
            matrix[i, start_index:end_index+1] = trajectory_array
    
    except:
        continue

# np.save(file_name, matrix)

db.close()
pymeos_finalize()
total_time = time.time() - now
frames_for_30_fps= 30 * total_time
print(f"================================================================     Matrix {begin_frame} created in {total_time} seconds, {frames_for_30_fps} frames for 30 fps animation.")
# Out:
# ================================================================     Matrix 240 created in 12.534109115600586 seconds, 376.0232734680176 frames for 30 fps animation.

# %%
len(rows)
# Out:
# 5821

# %%
np.count_nonzero(matrix != 'POINT EMPTY')
# Out:
# 864839

# %% [markdown]
# # Measuring nditer vs for loop for feature generation

# %%
# %%timeit

empty_point_wkt = Point().wkt  # "POINT EMPTY"
# create a numpy array of size len(ids_list) with empty_point_wkt
starting_points = np.full((1, 5821), empty_point_wkt, dtype=object)

qgis_fields_list = []

for wkt in np.nditer(starting_points, flags=['refs_ok']):
    feat = ["vlayer_fields"]
    feat.append("datetime_obj")  # Set its attributes
    # Create geometry from WKT string
    feat.append(wkt.item())
    qgis_fields_list.append(feat)
# Out:
# 962 µs ± 39.9 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
# %%timeit

empty_point_wkt = Point().wkt  # "POINT EMPTY"

qgis_fields_list = []

for i in range(5821):
    feat = ["vlayer_fields"]
    feat.append("datetime_obj")  # Set its attributes
    # Create geometry from WKT string
    feat.append(empty_point_wkt)
    qgis_fields_list.append(feat)
# Out:
# 378 µs ± 2.94 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# # Removing old files

# %%
import shutil

# Path to the directory
directory_path = f'/home/ali/matrices/'

shutil.rmtree(directory_path)

# %%
# create directory to store the matrices
os.makedirs(directory_path)
